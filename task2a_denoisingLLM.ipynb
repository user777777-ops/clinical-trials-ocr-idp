# %% [markdown]
# # Denoising text with an LLM before the Embedding.

# %% [markdown]
#  We will use the output from easyOCR, the highest quality OCR so far and also try with the quickest one we have which is pytesseract.
#  EasyOCR from what I've seen barely needs denoising, on the other hand pytesseract really does, we will see which is better.
#
#  For the LLM's I will investigate on locally installed ones later on. Right now, we will use the groq API, that offers a certain amount of tokens and charachters for free. One of the advantages of Groq is that instead of using GPU or CPU they developped language processing units(LPU) so the models are apparently extremely quick.
#
# We will prepare the input by leaving it in the folder [task2_prompts](./task2_prompts/)
# There are two folders with the two of the possible OCR results

# %% [markdown]
# ## Index
#
# 1. **Introduction**
#     - [Denoising text with an LLM before the Embedding.](#denoising-text-with-an-llm-before-the-embedding)
#
#     2. **OCR Approaches**
#         - [EasyOCR and pytesseract comparison](#ocr-approaches)
#         - [Input preparation and folder structure](#ocr-approaches)
#
#     3. **LLM Denoising Experiments**
#         - [llama-3.3-70b-versatile](#llama-3370b-versatile)
#           - [pyTessearct input](#pytessearct-input)
#           - [Easy OCR input](#easy-ocr-input)
#         - [mistral-saba-24b](#mistral-saba-24b)
#           - [pyTessearct input](#pytessearct-input-1)
#           - [Easy OCR input](#easy-ocr-input-1)
#         - [qwen-qwq-32b](#qwen-qwq-32b)
#           - [pyTessearct input](#pytessearct-input-2)
#           - [Easy OCR input](#easy-ocr-input-2)

# %% [markdown]
# ## llama-3.3-70b-versatile

# %% [markdown]
# ### pyTessearct input

# %%
# %pip install python-dotenv
# %pip install groq

# %%
import os


from groq import Groq

print("before OCR:")
with open('task2_prompts/prompting_tesseract.txt','r') as file:
    print(file.read())

client = Groq(

    # This is the default and can be omitted

    api_key=os.environ.get("GROQ_API_KEY"),

)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "You are an expert in cleaning OCR-extracted medical documents. "
                "Your task is to correct errors while preserving clinical accuracy. "
                "Follow these rules strictly:\n"
                "1. Fix OCR artifacts (e.g., 'c0ugh' → 'cough'), but NEVER alter valid medical terms.\n"
                "2. Remove non-text noise (stray symbols, headers/footers).\n"
                "3. Retain original formatting (lists, bullet points) where meaningful.\n"
                "4. Return ONLY the cleaned text, no explanations."
            )
        },
        {
            "role": "user",
            "content": (
                "Denoise this OCR-extracted medical document for embedding:\n\n"
                "=== INPUT TEXT ===\n"
                f"{open('task2_prompts/prompting_tesseract.txt', encoding='utf-8').read()}\n"
                "=== END INPUT ==="
            )
        }
    ],
    model="llama-3.3-70b-versatile",
    temperature=0.2,  # Reduce randomness for factual accuracy
    max_tokens=4096   # Ensure long documents are fully processed
)



print(chat_completion.choices[0].message.content)
# Out:
# before OCR:
# Copie électronique LABORATOIRE DE BIOLOGIE MEDICALE C LABO    N° FINESS :   -  -  @:  &:    - Biologiste(s) Médical(aux) Docteur     Madame    CABINET MEDICAL " "      (100) Copie a : Docteur    , DR  X Demande n° 01/02/ -LABO--TP Edité le, lundi 1 février 2021 Copie a : Docteur    , DR Patient né(e)   le   FSE Tiers payant  -  Prélevements effectués par le laboratoire le 01/02/21 a 10H27 Vos résultats sur internet : Accés sécurisé, rapide, gratuit, pratique, @coresponsable 1) Communiquez votre mail au laboratoire 2) Recevez un email dés que vos résultats sont disponibles 3) Cliquez sur le lien INFORMATION COVID-19 Rendez-vous sur notre site internet dédié pour connaitre notre organisation : https:// .fr/depistage-covid-19/ ia = Hematologie Valeurs de référence Antériorités v Hémogramme (Sang total - Variation d'impédance, photométrie, cytométrie en flux)  -   HEMatieS .......cccccecececeeeeeeeeeeeeeeeeeeeees 4,94 Téra/L 3,80 a 5,90 4,97 HEMOGIODING ........cceeeeeeeeeeeeeee seen enenees 13,6 g/d 11,54 17,5 13,8 8,4 mmol/L 7,14 10,9 HEMatocrite ........cccccecseeeeeeeeeneeeeneeuenes 41,1 % 34,0 & 53,0 41,8 VIG LM. coc cccccccceeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeees 83,1 #0 76,0 4 96,0 84,0 T.C.MLH. .cccccecccceeeeeeeeeeeeeeeeeeeeeaeeeenenes 27,4 pg 24,4 & 34,0 27,7 C.CLM LH. ccccecceceseeeeeeeeeeeeneeeeeeeeeeeeneears 33,0 g/at 31,0 a 36,0 32,9 Index d'aniSOCytOSe .........cceeeee eee eeeeeeee 13,7 10 4 16 14,1 LEUCOCYLES ....cceccececeee eee eee eens eae eeeeeeeeas 6,5 Giga/t 3,84 11,0 7,8 Polynucléaires neutrophiles ... 58,1 % 3,780 G/L 1,40 a 7,70 4,240 Polynucléaires éosinophiles ... 3,1 % 0,200 c/- 0,02 a 0,58 0,200 Polynucléaires basophiles ..... 0,9 % 0,060 G/L 0,00 4 0,11 0,060 Lymphocytes ..........cceeeeeee 32,4 % 2,110 G/L 1,00 a 4,80 2,870 MONOCYtES .....cceeeeeeee eee eenes 5,5 % 0,360 G/L 0,15 4 1,00 0,420  V PIAQUELEES 20... cecececeeeeeeeeeeeeeeeeeeeeeeeeeeees 228 Giga/L 150 a 445 213 (Sang total - Variation d'impédance - Beckman Coulter)  -  VPM. ..ccccccccceeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeegs 9,7 f Inf. 2 11,0 10,2 EFC ;   Biologiste Nous vous informons que conformément a la réglementation en vigueur, vos échantillons biologiques sont conservés pour une période réglementée puis détruits. Toutefois durant cette période dé conservation vos échantillons biologiques et vos données personnelles fn y étant attachées peuvent étre distribués et utilisés 4 des fins exclusives de contréle des dispositifs médicaux de diagnostic in vitro et/ou des comparaisons de méthodes, sauf opposition de votre part 4 manifester 4 tout moment auprés du secrétariat médical de votre laboratoire dont I’adresse est disponible via le lien suivant : https:// .fr/nos-laboratoires, et ce, en application des dispositions de I’article L 1211-2 du Code de la Santé Publique. Conformément a la réglementation sur la protection des données personnelles, vous disposez, & tout moment, d’un droit d’opposition, d’accés, de rectification, d’effacement, de limitation et de portabilité s’agissant du traitement de vos données personnelles. Pour cela, merci vous rendre sur le site internet << suivant https:// . fr/politique-de-confidentialite-rgpd/ Oo LABORATOIRE DE BIOLOGIE MEDICALE SIEGE SOCIAL -   -   Page 1/5 a MEMBRE DU GROUPE ’ie —Z Liste des Laboratoires de biologie médicale sur www. .fr Demande n° 01/02/ ME    v Vitesse de sédimentation ...........ccceceeeeees 11 mm Inf a 26 (Sang total - Photométrie capillaire)  -  Protéines Sériques Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramétres dosés en chimiluminescence. (ABC — juillet/aoat 2017, cf note sur https://.fr/espace-pro/). Valeurs de référence Antériorités UV FOSritiNe 10... ccc eeeec cee eeeee eee eee eeeeeeeeeeeees 43 ng/mt 15 a 150 (Sang - Immunoturbidimétrie latex - Roche)  -  97 pmol/L 34 & 337 *Pour les patients de plus de 60 ans, il n'existe pas de consensus sur les valeurs de référence ; a titre indicatif, nous vous signalons les valeurs ...
# Demande n° 01/02/
#
# Médecin traitant : Docteur    , DR
# Patient : Madame
# Date de naissance :
# Date de prélèvement : 01/02/21
# Heure de prélèvement : 10H27
#
# Hématologie :
# - Hémogramme (Sang total - Variation d'impédance, photométrie, cytométrie en flux)
#   - Hématie : 4,94 Téra/L (3,80 - 5,90)
#   - Hémoglobine : 13,6 g/dl (11,54 - 17,5)
#   - Hematocrite : 41,1 % (34,0 - 53,0)
#   - VGM : 83,1 fL (76,0 - 96,0)
#   - TCMH : 27,4 pg (24,4 - 34,0)
#   - CLMH : 33,0 g/dl (31,0 - 36,0)
#   - Index d'anisocytose : 13,7 (10 - 16)
#   - Leucocytes : 6,5 Giga/L (3,84 - 11,0)
#     - Polynucléaires neutrophiles : 58,1 % (1,40 - 7,70)
#     - Polynucléaires éosinophiles : 3,1 % (0,02 - 0,58)
#     - Polynucléaires basophiles : 0,9 % (0,00 - 0,11)
#     - Lymphocytes : 32,4 % (1,00 - 4,80)
#     - Monocytes : 5,5 % (0,15 - 1,00)
#
# Plaquettes : 228 Giga/L (150 - 445)
#
# Biochimie :
# - Glycémie à jeun : 5,60 mmol/L (4,11 - 5,89)
# - Triglycérides : 1,64 mmol/L (Inf - 1,70)
# - Cholestérol LDL : 1,74 mmol/L (Inf - 4,12)
# - Cholestérol HDL : 1,04 mmol/L (Sup à 1,04)
# - Cholestérol total : 3,53 mmol/L (Inf - 5,18)
#
# Fonction rénale :
# - Créatinine : 82 pmol/L (45 - 84)
# - DFG estimé d'après Lewey (MDRD) : 73 ml/min/1,73m2
# - DFG estimé d'après l'équation CKD-EPI : 85 ml/min/1,73m2
#
# Fer et transferrine :
# - Fer : 15,3 pmol/L (9,0 - 30,4)
# - Transferrine : 2,4 g/L (2,04 - 3,6)
# - Capacité totale de saturation en fer de la transferrine : 335 μg/100mL (250 - 500)
# - Coefficient de saturation de la transferrine : 25,5 % (15 - 45)
#
# Hormonologie :
# - FSH : 8,3 U/L
# - LH : 6,6 U/L
# - T4L : 12,90 pmol/L (12,00 - 21,90)
# - TSH : 7,39 μU/L (0,27 - 4,20)
#
# Sérologie :
# - Anticorps totaux SARS Cov2 (IgG+IgM) : Négatif
#
# Note : Les résultats doivent être interprétés par un médecin en tenant compte du contexte clinique et des antécédents médicaux du patient.

# %% [markdown]
# ### Easy OCR input

# %%
import os


from groq import Groq


client = Groq(

    # This is the default and can be omitted

    api_key=os.environ.get("GROQ_API_KEY"),

)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "You are an expert in cleaning OCR-extracted medical documents. "
                "Your task is to correct errors while preserving clinical accuracy. "
                "Follow these rules strictly:\n"
                "1. Fix OCR artifacts (e.g., 'c0ugh' → 'cough'), but NEVER alter valid medical terms.\n"
                "2. Remove non-text noise (stray symbols, headers/footers).\n"
                "3. Retain original formatting (lists, bullet points) where meaningful.\n"
                "4. Return ONLY the cleaned text, no explanations."
            )
        },
        {
            "role": "user",
            "content": (
                "Denoise this OCR-extracted medical document for embedding:\n\n"
                "=== INPUT TEXT ===\n"
                f"{open('task2_prompts/prompting_easy.txt', encoding='utf-8').read()}\n"
                "=== END INPUT ==="
            )
        }
    ],
    model="llama-3.3-70b-versatile",
    temperature=0.2,  # Reduce randomness for factual accuracy
    max_tokens=4096   # Ensure long documents are fully processed
)



print(chat_completion.choices[0].message.content)

# %% [markdown]
# ## mistral-saba-24b

# %% [markdown]
# ### pyTessearct input

# %%
import os


from groq import Groq


print("before OCR:")
with open('task2_prompts/prompting_tesseract.txt','r') as file:
    print(file.read())


client = Groq(

    # This is the default and can be omitted

    api_key=os.environ.get("GROQ_API_KEY"),

)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "You are an expert in cleaning OCR-extracted medical documents. "
                "Your task is to correct errors while preserving clinical accuracy. "
                "Follow these rules strictly:\n"
                "1. Fix OCR artifacts (e.g., 'c0ugh' → 'cough'), but NEVER alter valid medical terms.\n"
                "2. Remove non-text noise (stray symbols, headers/footers).\n"
                "3. Retain original formatting (lists, bullet points) where meaningful.\n"
                "4. Return ONLY the cleaned text, no explanations."
            )
        },
        {
            "role": "user",
            "content": (
                "Denoise this OCR-extracted medical document for embedding:\n\n"
                "=== INPUT TEXT ===\n"
                f"{open('task2_prompts/prompting_tesseract.txt', encoding='utf-8').read()}\n"
                "=== END INPUT ==="
            )
        }
    ],
    model="mistral-saba-24b",
    temperature=0.2,  # Reduce randomness for factual accuracy
    max_tokens=4096   # Ensure long documents are fully processed
)



print(chat_completion.choices[0].message.content)
# Out:
# before OCR:
# Copie électronique LABORATOIRE DE BIOLOGIE MEDICALE C LABO    N° FINESS :   -  -  @:  &:    - Biologiste(s) Médical(aux) Docteur     Madame    CABINET MEDICAL " "      (100) Copie a : Docteur    , DR  X Demande n° 01/02/ -LABO--TP Edité le, lundi 1 février 2021 Copie a : Docteur    , DR Patient né(e)   le   FSE Tiers payant  -  Prélevements effectués par le laboratoire le 01/02/21 a 10H27 Vos résultats sur internet : Accés sécurisé, rapide, gratuit, pratique, @coresponsable 1) Communiquez votre mail au laboratoire 2) Recevez un email dés que vos résultats sont disponibles 3) Cliquez sur le lien INFORMATION COVID-19 Rendez-vous sur notre site internet dédié pour connaitre notre organisation : https:// .fr/depistage-covid-19/ ia = Hematologie Valeurs de référence Antériorités v Hémogramme (Sang total - Variation d'impédance, photométrie, cytométrie en flux)  -   HEMatieS .......cccccecececeeeeeeeeeeeeeeeeeeeees 4,94 Téra/L 3,80 a 5,90 4,97 HEMOGIODING ........cceeeeeeeeeeeeeee seen enenees 13,6 g/d 11,54 17,5 13,8 8,4 mmol/L 7,14 10,9 HEMatocrite ........cccccecseeeeeeeeeneeeeneeuenes 41,1 % 34,0 & 53,0 41,8 VIG LM. coc cccccccceeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeees 83,1 #0 76,0 4 96,0 84,0 T.C.MLH. .cccccecccceeeeeeeeeeeeeeeeeeeeeaeeeenenes 27,4 pg 24,4 & 34,0 27,7 C.CLM LH. ccccecceceseeeeeeeeeeeeneeeeeeeeeeeeneears 33,0 g/at 31,0 a 36,0 32,9 Index d'aniSOCytOSe .........cceeeee eee eeeeeeee 13,7 10 4 16 14,1 LEUCOCYLES ....cceccececeee eee eee eens eae eeeeeeeeas 6,5 Giga/t 3,84 11,0 7,8 Polynucléaires neutrophiles ... 58,1 % 3,780 G/L 1,40 a 7,70 4,240 Polynucléaires éosinophiles ... 3,1 % 0,200 c/- 0,02 a 0,58 0,200 Polynucléaires basophiles ..... 0,9 % 0,060 G/L 0,00 4 0,11 0,060 Lymphocytes ..........cceeeeeee 32,4 % 2,110 G/L 1,00 a 4,80 2,870 MONOCYtES .....cceeeeeeee eee eenes 5,5 % 0,360 G/L 0,15 4 1,00 0,420  V PIAQUELEES 20... cecececeeeeeeeeeeeeeeeeeeeeeeeeeeees 228 Giga/L 150 a 445 213 (Sang total - Variation d'impédance - Beckman Coulter)  -  VPM. ..ccccccccceeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeegs 9,7 f Inf. 2 11,0 10,2 EFC ;   Biologiste Nous vous informons que conformément a la réglementation en vigueur, vos échantillons biologiques sont conservés pour une période réglementée puis détruits. Toutefois durant cette période dé conservation vos échantillons biologiques et vos données personnelles fn y étant attachées peuvent étre distribués et utilisés 4 des fins exclusives de contréle des dispositifs médicaux de diagnostic in vitro et/ou des comparaisons de méthodes, sauf opposition de votre part 4 manifester 4 tout moment auprés du secrétariat médical de votre laboratoire dont I’adresse est disponible via le lien suivant : https:// .fr/nos-laboratoires, et ce, en application des dispositions de I’article L 1211-2 du Code de la Santé Publique. Conformément a la réglementation sur la protection des données personnelles, vous disposez, & tout moment, d’un droit d’opposition, d’accés, de rectification, d’effacement, de limitation et de portabilité s’agissant du traitement de vos données personnelles. Pour cela, merci vous rendre sur le site internet << suivant https:// . fr/politique-de-confidentialite-rgpd/ Oo LABORATOIRE DE BIOLOGIE MEDICALE SIEGE SOCIAL -   -   Page 1/5 a MEMBRE DU GROUPE ’ie —Z Liste des Laboratoires de biologie médicale sur www. .fr Demande n° 01/02/ ME    v Vitesse de sédimentation ...........ccceceeeeees 11 mm Inf a 26 (Sang total - Photométrie capillaire)  -  Protéines Sériques Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramétres dosés en chimiluminescence. (ABC — juillet/aoat 2017, cf note sur https://.fr/espace-pro/). Valeurs de référence Antériorités UV FOSritiNe 10... ccc eeeec cee eeeee eee eee eeeeeeeeeeeees 43 ng/mt 15 a 150 (Sang - Immunoturbidimétrie latex - Roche)  -  97 pmol/L 34 & 337 *Pour les patients de plus de 60 ans, il n'existe pas de consensus sur les valeurs de référence ; a titre indicatif, nous vous signalons les valeurs ...
# Copie électronique
# LABORATOIRE DE BIOLOGIE MEDICALE C LABO
# N° FINESS :
#  -  -
# @:  &:
#   - Biologiste(s) Médical(aux)
# Docteur
# Madame
# CABINET MEDICAL " "
#
#   (100)
# Copie à : Docteur    , DR
# X
# Demande n° 01/02/ -LABO--TP
# Edité le, lundi 1 février 2021
# Copie à : Docteur    , DR
# Patient né(e)   le
#
# FSE Tiers payant  -
# Prélevements effectués par le laboratoire le 01/02/21 à 10H27
# Vos résultats sur internet : Accès sécurisé, rapide, gratuit, pratique,
# 1) Communiquez votre mail au laboratoire
# 2) Recevez un email dès que vos résultats sont disponibles
# 3) Cliquez sur le lien INFORMATION COVID-19
# Rendez-vous sur notre site internet dédié pour connaître notre organisation :
# https:// .fr/depistage-covid-19/
# ia = Hematologie
# Valeurs de référence
# Antériorités
# v Hémogramme (Sang total - Variation d'impédance, photométrie, cytométrie en flux)
#  -
#
# HEMATIES 4,94 Téra/L 3,80 à 5,90 4,97
# HEMOGLOBINE 13,6 g/dL 11,54 à 17,5 13,8
# HEMATOCRITE 41,1 % 34,0 à 53,0 41,8
# VGM 83,1 fL 76,0 à 96,0 84,0
# TCMH 27,4 pg 24,4 à 34,0 27,7
# CCMH 33,0 g/dL 31,0 à 36,0 32,9
# Index d'anisocytose 13,7 10 à 16 14,1
# LEUCOCYTES 6,5 Giga/L 3,84 à 11,0 7,8
# Polynucléaires neutrophiles 58,1 % 3,780 G/L 1,40 à 7,70 4,240
# Polynucléaires éosinophiles 3,1 % 0,200 G/L 0,02 à 0,58 0,200
# Polynucléaires basophiles 0,9 % 0,060 G/L 0,00 à 0,11 0,060
# Lymphocytes 32,4 % 2,110 G/L 1,00 à 4,80 2,870
# MONOCYTES 5,5 % 0,360 G/L 0,15 à 1,00 0,420
#
# PLAQUELEES 228 Giga/L 150 à 445 213
# (Sang total - Variation d'impédance - Beckman Coulter)
#  -
# VPM 9,7 fL 2 11,0 10,2
# EFC
#   Biologiste
# Nous vous informons que conformément à la réglementation en vigueur, vos échantillons biologiques sont conservés pour une période réglementée puis détruits. Toutefois, durant cette période de conservation, vos échantillons biologiques et vos données personnelles y étant attachées peuvent être distribués et utilisés à des fins exclusives de contrôle des dispositifs médicaux de diagnostic in vitro et/ou des comparaisons de méthodes, sauf opposition de votre part à manifester à tout moment auprès du secrétariat médical de votre laboratoire dont l’adresse est disponible via le lien suivant : https:// .fr/nos-laboratoires, et ce, en application des dispositions de l’article L 1211-2 du Code de la Santé Publique.
# Conformément à la réglementation sur la protection des données personnelles, vous disposez, à tout moment, d’un droit d’opposition, d’accès, de rectification, d’effacement, de limitation et de portabilité s’agissant du traitement de vos données personnelles. Pour cela, merci de vous rendre sur le site internet suivant https:// .fr/politique-de-confidentialite-rgpd/
# LABORATOIRE DE BIOLOGIE MEDICALE
# SIEGE SOCIAL -   -
# Page 1/5
# MEMBRE DU GROUPE ’ie
# Liste des Laboratoires de biologie médicale sur www. .fr
# Demande n° 01/02/
# ME
# v Vitesse de sédimentation 11 mm/h 26 (Sang total - Photométrie capillaire)
#  -
# Protéines Sériques
# Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramètres dosés en chimiluminescence. (ABC — juillet/aoat 2017, cf note sur https://.fr/espace-pro/).
# Valeurs de référence
# Antériorités
# UV
# FOSRITINE 43 ng/mL 15 à 150 (Sang - Immunoturbidimétrie latex - Roche)
#  -
# 97 pmol/L 34 à 337
# *Pour les patients de plus de 60 ans, il n'existe pas de consensus sur les valeurs de référence ; à titre indicatif, nous vous signalons les valeurs de référence de l'adulte jusqu'à 60 ans.
# Enzymologie
# Valeurs de référence
# Antériorités
# v Transaminases S.G.O.T. (ASAT) 22 U/L Inf. 4 32 (Sang - Photométrie IFCC - Roche)
#  -
# v Transaminases S.G.P.T. (ALAT) 24 U/L Inf. 233 (Sang - Photométrie IFCC - Roche)
#  -
# Biochimie
# Valeurs de référence
# Antériorités
# v Glycémie à jeun 5,60 mmol/L 4,11 à 5,89 (Sang - Méthode enzymatique - Roche)
#  -
# 1,01 g/L 0,74 à 1,06
# L'OMS considère qu'une glycémie à jeun normale est inférieure à 6.10 mmol/L (1.10 g/L)
# v Aspect du SÉRUM
# Limpide
# v Triglycérides 1,64 mmol/L Inf. 1,70 (Sang - Méthode colorimétrique enzymatique - Roche)
#  -
# 1,44 g/L Inf. à 1,50
# v Calcul du Cholestérol L.D.L. 1,74 mmol/L Inf. 44,12 (Calcul à partir de la Formule de Friedewald)
# Valeur recommandée : < 4,12 mmol/L soit 1,60 g/L (HAS/AFSSAPS 2017)
# 0,68 g/L Inf. à 1,60
# v Cholestérol H.D.L. 1,04 mmol/L (Sang - Méthode colorimétrique enzymatique - Roche)
#  -
# Valeur recommandée : > 1,04 mmol/L soit 0,40 g/L (HAS 2017)
# 0,40 g/L
# v Cholestérol Total 3,53 mmol/L (Sang - Méthode colorimétrique enzymatique - Roche)
#  -
# 1,37 g/L
# Il n'y a plus de valeurs de référence pour le cholesterol total, le taux considéré comme usuel est <5,18 mmol/L (2,00 g/L) HAS 2008
# Conclusion : Bilan lipidique à interpréter en fonction du contexte clinique et des facteurs de risques cardio-vasculaires. L'interprétation du bilan lipidique s'effectue avec la valeur du Cholesterol-LDL et le niveau de RCV (Risque Cardio-Vasculaire) apprécié par le médecin traitant à l'aide de l'outil SCORE et/ou des facteurs de RCV.
#   Biologiste
# Page 2/5
# LABORATOIRE DE BIOLOGIE MEDICALE C LABO
# N° FINESS :
#  -  -
# @:  &:
#   - Biologiste(s) Médical(aux)
# Docteur
# Madame
# Demande n° 01/02/ -LABO--TP
# Edité le, lundi 1 février 2021
# v Estimation de la fonction rénale (DFG : Débit de Filtration Glomérulaire)
#
# Cr@atinine 82 pmol/L 45 à 84 64 (Sang - Méthode enzymatique - Roche)
#  -
# 9,3 mg/L 5,1 à 9,5 7,2
#
# DFG estimé d'après Lewey (MDRD) 73 mL/min/1.73m2 97
# Cette valeur calculée est à majorer de 21% chez un sujet ayant des origines africaines.
#
# DFG estimé d'après l'équation CKD-EPI 85 mL/min/1.73m2 Sup. à 60 115
# L'équation CKD-EPI présente les meilleures performances quel que soit le niveau de la fonction rénale. Le facteur de correction ethnique est en cours de validation (HAS 2011).
# Interprétation : Débit de Filtration Glomérulaire légèrement diminué
# v Fer Sérique 15,3 pmol/L 9,0 à 30,4 (Sang - Colorimétrie - Roche)
#  -
# 85 µg/100mL 50 à 170
# v Transferrine 2,4 g/L 2,0 à 3,6 (Sang - Immunoturbidimétrie - Roche)
#  -
# 30,2 mol/L 25,28 à 45,4
# v Capacité totale de saturation en fer de la Transferrine 335 µg/100mL 250 à 500 60,0 µmol/L
# v Coefficient de saturation de la Transferrine 25,5 % 15 à 43
# Hormonologie
# Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramètres dosés en chimiluminescence. (ABC — juillet/aoat 2017, cf note sur https://.fr/espace-pro/).
# Valeurs de référence
# Antériorités
# Hormones de la fertilité
# Date des dernières règles 30/01/21
# UV
# FLSH 8,3 U/L Cf tableau (Sang - Electrochimiluminescence - Roche)
#  -
# Valeurs de référence FEMME DE PLUS DE 17 ans
# Phase folliculaire : 3,5 à 12,5
# Pic ovulatoire 14,7 à 21,5
# Phase lutéale : 1,7 à 7,7
# Postménopause : 25,8 à 134,8
# Valeurs de référence HOMME DE PLUS DE 17 ans
# Hommes : 1,5 à 12,4
# Z iS) kL Wi fn
#   Biologiste
# LABORATOIRE DE BIOLOGIE MEDICALE
# SIEGE SOCIAL -   -
# Page 3/5
# MEMBRE DU GROUPE ’ie
# Liste des Laboratoires de biologie médicale sur www. .fr
# Demande n° 01/02/
# ME
# v LH 6,6 U/L Cf tableau (Sang - Electrochimiluminescence - Roche)
#  -
# Valeurs de référence FEMME DE PLUS DE 17 ans
# Phase folliculaire : 2,4 à 12,6
# Pic ovulatoire : 14 à 95,6
# Phase lutéale : 1,0 à 11,4
# Postménopause : 7,7 à 58,5
# Valeurs de référence HOMME DE PLUS DE 17 ans
# Hommes : 1,7 à 8,6
# a a Thyroide
# v Thyroxine libre (T4L) 12,90 pmol/L 12,00 à 21,90 (Sang - Electrochimiluminescence - Roche)
#  -
# 10,02 ng/L 9,30 à 17,00
# v TSH ultra-Sensible 7,39 mU/L 0,27 à 4,20 (Sang - Electrochimiluminescence - Roche)
#  -
# Immunologie
# Sérologie à interpréter en dehors de tout traitement par gammaglobulines et transfusion sanguine récente. Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats de certains paramètres dosés en chimiluminescence. (ABC — juillet/aoat 2017, cf note sur https://.fr/espace-pro/).
# Les résultats de sérologie doivent être interprétés avec prudence du fait des incertitudes de mesure, de la spécificité ou de la sensibilité relative des tests, ou de prélévements effectués durant la phase d'incubation. En fonction des signes cliniques et pour des résultats proches des seuils, il peut donc s'avérer nécessaire de contrôler les résultats.
# Valeurs de référence
# Antériorités
# Sérologie SARS-CoV-2 (Covid-19)
# v Anticorps totaux SARS Cov2 (IgG+IgM) Négatif (Sang - Electrochimiluminescence - Roche)
#  -
# | ale (> 0,1 Négatif <1 ; Positif > 1 Absence d'anticorps. A confronter au contexte clinique, à l'anamnése et aux autres résultats biologiques.
# Information pour la sérologie du COVID-19 : depuis le 02 juin 2020, la prise en charge de cet acte est limitée aux situations suivantes :
# — Diagnostic initial de patients symptomatiques graves hospitalisés, si tableau clinique ou scanographique évocateur et RT-PCR négative.
# — Diagnostic de rattrapage de patients symptomatiques graves hospitalisés, mais n'ayant pas été en mesure de réaliser un test RT-PCR dans l'intervalle des sept jours suivant l'apparition des symptômes.
# — Diagnostic initial de patients symptomatiques sans signe de gravité suivis en ville si tableau clinique évocateur et test RT-PCR négatif.
# — Diagnostic de rattrapage chez des patients symptomatiques avec suspicion clinique sans signe de gravité mais n'ayant pas été en mesure de réaliser un test RT-PCR dans l'intervalle des sept jours suivant l'apparition des symptômes.
# — Diagnostic chez les professionnels soignants non symptomatiques, en complément du dépistage et de la détection de personne-contact par RT-PCR selon les recommandations en vigueur, si la RT-PCR est négative.
# — Diagnostic chez les personnels d'hébergement collectif (établissements sociaux et médico sociaux, prisons, casernes, résidences universitaires, internants) non symptomatiques en complément du dépistage et de la détection de personne-contact par RT-PCR selon les recommandations en vigueur, si la RT-PCR est négative.
# — Diagnostic étiologique à distance chez des patients symptomatiques sans signe de gravité diagnostiqué cliniquement mais n'ayant pas fait l'objet d'une RT-PCR.
# En dehors de ces situations, l'acte doit alors être prescrit obligatoirement avec la mention « Hors nomenclature » ou « HN » (HAS et NABM 2020). Merci de préciser sur votre prescription si une PCR a été réalisée ant

# %% [markdown]
# ### Easy OCR input

# %%
import os


from groq import Groq


client = Groq(

    # This is the default and can be omitted

    api_key=os.environ.get("GROQ_API_KEY"),

)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "You are an expert in cleaning OCR-extracted medical documents. "
                "Your task is to correct errors while preserving clinical accuracy. "
                "Follow these rules strictly:\n"
                "1. Fix OCR artifacts (e.g., 'c0ugh' → 'cough'), but NEVER alter valid medical terms.\n"
                "2. Remove non-text noise (stray symbols, headers/footers).\n"
                "3. Retain original formatting (lists, bullet points) where meaningful.\n"
                "4. Return ONLY the cleaned text, no explanations."
            )
        },
        {
            "role": "user",
            "content": (
                "Denoise this OCR-extracted medical document for embedding:\n\n"
                "=== INPUT TEXT ===\n"
                f"{open('task2_prompts/prompting_easy.txt', encoding='utf-8').read()}\n"
                "=== END INPUT ==="
            )
        }
    ],
    model="mistral-saba-24b",
    temperature=0.2,  # Reduce randomness for factual accuracy
    max_tokens=4096   # Ensure long documents are fully processed
)



print(chat_completion.choices[0].message.content)
# Out:
# Copie électronique
#
# LABORATOIRE DE BIOLOGIE MÉDICALE
# 6
#
#
# No FINESS 34 3
# 2
#
#
#
# Biologiste(s) Médical(aux)
#
# Docteur
# Madame
#
# CABINET MEDICAL " "
#
#
#
# Copie à
# Docteur    , DR
#
# Demande n° 01/02/
# LABO--TP
# Edité le, lundi 1 février 2021
#
# Copie à
# Docteur    , DR
#
# Patient né(e)   le
#
# FSE
# Tiers payant
#
#
#
# Prélèvements effectués par le laboratoire le 01/02/21 à 10H27
#
# Vos résultats sur internet
# Accès sécurisé, rapide, gratuit, pratique, écoresponsable
# 1) Communiquez votre mail au laboratoire
# 2) Recevez un email dès vos résultats sont disponibles
# 3) Cliquez sur le lien
#
# INFORMATION COVID-19
# Rendez-vous sur notre site internet dédié pour connaître notre organisation
# https:// .fr/depistage-covid-19/
#
# Hématologie
# Valeurs de référence
# Antériorités
# Hémogramme (Sang total Variation d'impédance, photométrie, cytométrie en flux)
#
#
# Hématies 4,94 Téra/L 3,80 à 5,90 4,97
# Hémoglobine 13,6 g/dL 11,5 à 17,5 13,8
# 8,4 mmol/L 7,1 à 10,9
# Hématocrite 41,1 % 34,0 à 53,0 41,8
# VG.M 83,1 fL 76,0 à 96,0 84,0
# TC.MH 27,4 pg 24,4 à 34,0 27,7
# C.C.MH 33,0 g/dL 31,0 à 36,0 32,9
# Index d'anisocytose 13,7 10 à 16 14,1
# Leucocytes 6,5 Giga/L 3,8 à 11,0 7,8
# Polynucléaires neutrophiles 58,1 % 3,780 G/L 1,40 à 7,70 4,240
# Polynucléaires éosinophiles 3,1 % 0,200 G/L 0,02 à 0,58 0,200
# Polynucléaires basophiles 0,9 % 0,060 G/L 0,00 à 0,11 0,060
# Lymphocytes 32,4 % 2,110 G/L 1,00 à 4,80 2,870
# Monocytes 5,5 % 0,360 G/L 0,15 à 1,00 0,420
#
#
# Plaquettes 228 Giga/L 150 à 445 213
# (Sang total Variation d'impédance Beckman Coulter)
#
# VPM 9,7 fL Inf. à 11,0 10,2
#
#
# Biologiste
#
# Nous vous informons que conformément à la réglementation en vigueur, vos échantillons biologiques sont conservés pour une période réglementée puis détruits. Toutefois, durant cette période de conservation, vos échantillons biologiques et vos données personnelles étant attachées peuvent être distribués et utilisés à des fins exclusives de contrôle des dispositifs médicaux de diagnostic in vitro et/ou des comparaisons de méthodes sauf opposition de votre part manifestée à tout moment auprès du secrétariat médical de votre laboratoire dont l'adresse est disponible via le lien suivant https:// .fr/nos-laboratoires; et ce en application des dispositions de l'article 1211-2 du Code de la Santé Publique.
#
# Conformément à la réglementation sur la protection des données personnelles, vous disposez, à tout moment, d'un droit d'opposition, d'accès, de rectification, d'effacement, de limitation et de portabilité concernant le traitement de vos données personnelles. Pour cela, merci de vous rendre sur le site internet suivant https:// .fr/politique-de-confidentialite-rgpa/
#
# LABORATOIRE DE BIOLOGIE MÉDICALE
# SIÈGE SOCIAL
#
#
#
# Page 1/5
# MEMBRE DU GROUPE
# Liste des Laboratoires de biologie médicale sur www. .fr
#
# Demande n° 01/02/
# ME
#
# Vitesse de sédimentation 11 mm Inf à 26
# (Sang total Photométrie capillaire)
#
#
# Protéines Sériques
# Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramètres dosés en chimiluminescence: (ABC juillet-août 2017, cf note sur https://.fr/lespace-prol).
#
# Valeurs de référence
# Antériorités
# Ferritine 43 ng/mL 15 à 150
# (Sang Immunoturbidimétrie latex Roche)
#
# 97 pmol/L 34 à 337
#
# Pour les patients de plus de 60 ans, il n'existe pas de consensus sur les valeurs de référence à titre indicatif, nous vous signalons les valeurs de référence de l'adulte jusqu'à 60 ans.
#
# Enzymologie
# Valeurs de référence
# Antériorités
# Transaminases S.G.0.T. (ASAT) 22 U/L Inf. à 32
# (Sang Photométrie IFCC Roche)
#
# Transaminases S.G.PT. (ALAT) 24 U/L Inf. à 33
# (Sang Photométrie IFCC Roche)
#
#
# Biochimie
# Valeurs de référence
# Antériorités
# Glycémie à Jeun 5,60 mmol/L 4,11 à 5,89
# (Sang Méthode enzymatique Roche)
#
# 1,01 g/L 0,74 à 1,06
#
# L'OMS considère qu'une glycémie à jeun normale est inférieure à 6.10 mmol/L (1.10 g/L)
#
# Aspect du sérum Limpide
# Triglycérides 1,64 mmol/L Inf. à 1,70
# (Sang Méthode colorimétrique enzymatique Roche)
#
# 1,44 g/L Inf. à 1,50
#
# Calcul du Cholestérol L.D.L 1,74 mmol/L Inf. à 4,12
# (Calcul à partir de la Formule de Friedewald)
# 0,68 g/L Inf. à 1,60
# Valeur recommandée < 4,12 mmol/L soit 1,60 g/L (HAS/AFSSAPS 2017)
#
# Cholestérol H.D.L. 1,04 mmol/L
# (Sang Méthode colorimétrique enzymatique Roche)
#
# Valeur recommandée > 1,04 mmol/L soit 0,40 g/L (HAS 2017)
# 0,40 g/L
#
# Cholestérol Total 3,53 mmol/L
# (Sang Méthode colorimétrique enzymatique Roche)
#
# 1,37 g/L
#
# Il n'y a plus de valeurs de référence pour le cholesterol total, le taux considéré comme usuel est <5,18 mmol/L (2,00 g/L) HAS 2008
#
# Conclusion
# Bilan lipidique à interpréter en fonction du contexte clinique et des facteurs de risques cardio-vasculaires. L'interprétation du bilan lipidique s'effectue avec la valeur du Cholesterol-LDL et le niveau de RCV (Risque Cardio-Vasculaire) apprécié par le médecin traitant à l'aide de l'outil SCORE et/ou des facteurs de RCV.
#
#
# Biologiste
#
# Page 2/5
#
# LABORATOIRE DE BIOLOGIE MÉDICALE
# 6
#
#
# No FINESS 34 001 868
# 8
#
#
#
# Biologiste(s) Médical(aux)
#
# Docteur
# Madame
#
# Demande 01/02/
# LABO--TP
# Edité le, lundi 1 février 2021
#
# Estimation de la fonction rénale (DFG Débit de Filtration Glomérulaire)
#
# Créatinine 82 pmol/L 45 à 84 64
# (Sang Méthode enzymatique Roche)
#
# 9,3 mg/L 5,1 à 9,5 7,2
#
#
# DFG estimé d'après Lewey (MDRD) 73 mL/min/1.73m2 97
# Cette valeur calculée est à majorer de 21% chez un sujet ayant des origines africaines.
#
#
# DFG estimé d'après l'équation CKD-EPI 85 mL/min/1.73m2 Sup. à 60 115
# L'équation CKD-EPI présente les meilleures performances quel que soit le niveau de la fonction rénale. Le facteur de correction ethnique est en cours de validation (HAS 2011)
#
# Interprétation
# Débit de Filtration Glomérulaire légèrement diminué
#
# Fer sérique 15,3 umol/L 9,0 à 30,4
# (Sang Colorimétrie Roche)
#
# 85 ug/100mL 50 à 170
#
# Transferrine 2,4 g/L 2,0 à 3,6
# (Sang Immunoturbidimétrie Roche)
#
# 30,2 umol/L 25,2 à 45,4
#
# Capacité totale de saturation en fer de la transferrine 335 ug/100mL 250 à 500
# 60,0 umol/L
#
# Coefficient de saturation de la transferrine 25,5 % 15 à 35
#
# Hormonologie
# Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramètres dosés en chimiluminescence. (ABC juillet-août 2017, cf note sur https://.fr/lespace-prol).
#
# Valeurs de référence
# Antériorités
# Hormones_de_la_fertilité
# Date des dernières règles 30/01/21
# FS.H. 8,3 UI/L Cf tableau
# (Sang Electrochimiluminescence Roche)
#
#
# Valeurs de référence FEMME DE PLUS DE 17 ans
# Phase folliculaire 3.5 à 12.5
# Pic ovulatoire 4.7 à 21.5
# Phase lutéale 1.7 à 7.7
# Postménopause 25.8 à 134.8
#
# Valeurs de référence HOMME DE PLUS DE 17 ans
# Hommes 1.5 à 12.4
#
# LH. 6,6 U/L Cf tableau
# (Sang Electrochimiluminescence Roche)
#
#
# Valeurs de référence FEMME DE PLUS DE 17 ans
# Phase folliculaire 2.4 à 12.6
# Pic ovulatoire 14 à 95.6
# Phase lutéale 1.0 à 11.4
# Postménopause 7.7 à 58.5
#
# Valeurs de référence HOMME DE PLUS DE 17 ans
# Hommes 1.7 à 8.6
#
# Thyroïde
# Thyroxine libre (T4L) 12,90 pmol/L 12,00 à 21,90
# (Sang Electrochimiluminescence Roche)
#
# 10,02 ng/L 9,30 à 17,00
#
# T.S.H. ultra-sensible 7,39 mUI/L 0,27 à 4,20
# (Sang Electrochimiluminescence Roche)
#
#
# Immunologie
# Sérologie à interpréter en dehors de tout traitement par gammaglobulines et transfusion sanguine récente. Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats de certains paramètres dosés en chimiluminescence. (ABC juillet-août 2017, cf note sur https://.fr/lespace-prol).
#
# Les résultats de sérologie doivent être interprétés avec prudence du fait des incertitudes de mesure, de la spécificité ou de la sensibilité relative des tests, ou de prélèvements effectués durant la phase d'incubation. En fonction des signes cliniques et pour des résultats proches des seuils, il peut donc s'avérer nécessaire de contrôler les résultats.
#
# Valeurs de référence
# Antériorités
# Sérologie_SARS-CoV-2 (Covid-19)
# Anticorps totaux SARS Cov2 (IgG+IgM) Négatif
# (Sang Electrochimiluminescence Roche)
#
# Index 0,1 Négatif <1 Positif 2 1
# Absence d'anticorps. A confronter au contexte clinique, à l'anamnèse et aux autres résultats biologiques
#
# Information pour la sérologie du COVID-19
# Depuis le 02 juin 2020, la prise en charge de cet acte est limitée aux situations suivantes:
# Diagnostic initial de patients symptomatiques graves hospitalisés, si tableau clinique ou scanographique évocateur et RT-PCR négative
# Diagnostic de rattrapage de patients symptomatiques graves hospitalisés, mais n'ayant pas été en mesure de réaliser un test RT-PCR dans l'intervalle des sept jours suivant l'apparition des symptômes.
# Diagnostic initial de patients symptomatiques sans signe de gravité suivis en ville si tableau clinique évocateur et test RT-PCR négatif.
# Diagnostic de rattrapage chez des patients symptomatiques avec suspicion clinique sans signe de gravité mais n'ayant pas en mesure de réaliser un test RT-PCR dans l'intervalle des sept jours suivant l'apparition des symptômes.
# Diagnostic chez les professionnels soignants non symptomatiques, en complément du dépistage et de la détection de personne-contact par RT-PCR selon les recommandations en vigueur, si la RT-PCR est négative
# Diagnostic chez les personnels d'hébergement collectif (établissements sociaux et médico sociaux, prisons, casernes, résidences universitaires, internants) non symptomatiques en complément du dépistage et de la détection de personne-contact par RT-PCR selon les recommandations en vigueur, si la RT-PCR est négative.
# Diagnostic étiologique à distance chez des patients symptomatiques sans signe de gravité diagnostiqué cliniquement mais n'ayant pas fait l'objet d'une RT-PCR.
#
# En dehors de ces situations, l'acte doit alors être prescrit obligatoirement avec la mention Hors nomenclature 22 ou << HN (HAS et NABM 2020). Merci de préciser sur votre prescription si une PCR a été réalisée antérieurement et la date d'apparition des symptômes.
#
# Sérologie non indiquée dans le suivi post vaccinal (absence de détection des anticorps dirigés contre la protéine S). La réalisation du suivi du statut vaccinal par test sérologique n'est pas recommandé par les autorités sanitaires (HAS 2020).
#
#
# Biologiste
#
# Page 4/5
#
# Les données vous concernant collectées dans le cadre du présent examen biologique, en lien avec l'épidémie du Covid-19, sont enregistrées dans le système information national dénommé SI-DEP, mis en œuvre par la Direction e de la santé du ministère chargé des solidarités et de la santé, conformément aux dispositions de l'article 11 de la loi du 11 mai 2020 prorogeant l'état d'urgence sanitaire et de son décret d'application. Ce traitement d'intérêt public a pour finalité de centraliser les résultats des examens de dépistage Covid-19 en vue de leur réutilisation à des fins d'enquête sanitaire, de surveillance épidémiologique et de recherche via la plateforme des données de santé. Pour plus d'information sur ce traitement et vos droits, consultez le site du ministère des solidarités et de la santé (https://solidarites-/ministere/article/donnees-personnelles

# %% [markdown]
# ## qwen-qwq-32b

# %% [markdown]
# ### pyTessearct input

# %%
import os


from groq import Groq


print("before OCR:")
with open('task2_prompts/prompting_tesseract.txt','r') as file:
    print(file.read())


client = Groq(

    # This is the default and can be omitted

    api_key=os.environ.get("GROQ_API_KEY"),

)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "You are an expert in cleaning OCR-extracted medical documents. "
                "Your task is to correct errors while preserving clinical accuracy. "
                "Follow these rules strictly:\n"
                "1. Fix OCR artifacts (e.g., 'c0ugh' → 'cough'), but NEVER alter valid medical terms.\n"
                "2. Remove non-text noise (stray symbols, headers/footers).\n"
                "3. Retain original formatting (lists, bullet points) where meaningful.\n"
                "4. Return ONLY the cleaned text, no explanations."
            )
        },
        {
            "role": "user",
            "content": (
                "Denoise this OCR-extracted medical document for embedding:\n\n"
                "=== INPUT TEXT ===\n"
                f"{open('task2_prompts/prompting_tesseract.txt', encoding='utf-8').read()}\n"
                "=== END INPUT ==="
            )
        }
    ],
    model="qwen-qwq-32b",
    temperature=0.2,  # Reduce randomness for factual accuracy
    max_tokens=4096   # Ensure long documents are fully processed
)



print(chat_completion.choices[0].message.content)
# Out:
# before OCR:
# Copie électronique LABORATOIRE DE BIOLOGIE MEDICALE C LABO    N° FINESS :   -  -  @:  &:    - Biologiste(s) Médical(aux) Docteur     Madame    CABINET MEDICAL " "      (100) Copie a : Docteur    , DR  X Demande n° 01/02/ -LABO--TP Edité le, lundi 1 février 2021 Copie a : Docteur    , DR Patient né(e)   le   FSE Tiers payant  -  Prélevements effectués par le laboratoire le 01/02/21 a 10H27 Vos résultats sur internet : Accés sécurisé, rapide, gratuit, pratique, @coresponsable 1) Communiquez votre mail au laboratoire 2) Recevez un email dés que vos résultats sont disponibles 3) Cliquez sur le lien INFORMATION COVID-19 Rendez-vous sur notre site internet dédié pour connaitre notre organisation : https:// .fr/depistage-covid-19/ ia = Hematologie Valeurs de référence Antériorités v Hémogramme (Sang total - Variation d'impédance, photométrie, cytométrie en flux)  -   HEMatieS .......cccccecececeeeeeeeeeeeeeeeeeeeees 4,94 Téra/L 3,80 a 5,90 4,97 HEMOGIODING ........cceeeeeeeeeeeeeee seen enenees 13,6 g/d 11,54 17,5 13,8 8,4 mmol/L 7,14 10,9 HEMatocrite ........cccccecseeeeeeeeeneeeeneeuenes 41,1 % 34,0 & 53,0 41,8 VIG LM. coc cccccccceeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeees 83,1 #0 76,0 4 96,0 84,0 T.C.MLH. .cccccecccceeeeeeeeeeeeeeeeeeeeeaeeeenenes 27,4 pg 24,4 & 34,0 27,7 C.CLM LH. ccccecceceseeeeeeeeeeeeneeeeeeeeeeeeneears 33,0 g/at 31,0 a 36,0 32,9 Index d'aniSOCytOSe .........cceeeee eee eeeeeeee 13,7 10 4 16 14,1 LEUCOCYLES ....cceccececeee eee eee eens eae eeeeeeeeas 6,5 Giga/t 3,84 11,0 7,8 Polynucléaires neutrophiles ... 58,1 % 3,780 G/L 1,40 a 7,70 4,240 Polynucléaires éosinophiles ... 3,1 % 0,200 c/- 0,02 a 0,58 0,200 Polynucléaires basophiles ..... 0,9 % 0,060 G/L 0,00 4 0,11 0,060 Lymphocytes ..........cceeeeeee 32,4 % 2,110 G/L 1,00 a 4,80 2,870 MONOCYtES .....cceeeeeeee eee eenes 5,5 % 0,360 G/L 0,15 4 1,00 0,420  V PIAQUELEES 20... cecececeeeeeeeeeeeeeeeeeeeeeeeeeeees 228 Giga/L 150 a 445 213 (Sang total - Variation d'impédance - Beckman Coulter)  -  VPM. ..ccccccccceeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeegs 9,7 f Inf. 2 11,0 10,2 EFC ;   Biologiste Nous vous informons que conformément a la réglementation en vigueur, vos échantillons biologiques sont conservés pour une période réglementée puis détruits. Toutefois durant cette période dé conservation vos échantillons biologiques et vos données personnelles fn y étant attachées peuvent étre distribués et utilisés 4 des fins exclusives de contréle des dispositifs médicaux de diagnostic in vitro et/ou des comparaisons de méthodes, sauf opposition de votre part 4 manifester 4 tout moment auprés du secrétariat médical de votre laboratoire dont I’adresse est disponible via le lien suivant : https:// .fr/nos-laboratoires, et ce, en application des dispositions de I’article L 1211-2 du Code de la Santé Publique. Conformément a la réglementation sur la protection des données personnelles, vous disposez, & tout moment, d’un droit d’opposition, d’accés, de rectification, d’effacement, de limitation et de portabilité s’agissant du traitement de vos données personnelles. Pour cela, merci vous rendre sur le site internet << suivant https:// . fr/politique-de-confidentialite-rgpd/ Oo LABORATOIRE DE BIOLOGIE MEDICALE SIEGE SOCIAL -   -   Page 1/5 a MEMBRE DU GROUPE ’ie —Z Liste des Laboratoires de biologie médicale sur www. .fr Demande n° 01/02/ ME    v Vitesse de sédimentation ...........ccceceeeeees 11 mm Inf a 26 (Sang total - Photométrie capillaire)  -  Protéines Sériques Un traitement par la biotine (Vitamine B7, Vitamine B8 ou Vitamine H) peut fausser les résultats des paramétres dosés en chimiluminescence. (ABC — juillet/aoat 2017, cf note sur https://.fr/espace-pro/). Valeurs de référence Antériorités UV FOSritiNe 10... ccc eeeec cee eeeee eee eee eeeeeeeeeeeees 43 ng/mt 15 a 150 (Sang - Immunoturbidimétrie latex - Roche)  -  97 pmol/L 34 & 337 *Pour les patients de plus de 60 ans, il n'existe pas de consensus sur les valeurs de référence ; a titre indicatif, nous vous signalons les valeurs ...
#
# <think>
# Okay, let's tackle this OCR cleaning task. First, I need to go through the provided text carefully. The user wants the document denoised but keeping clinical accuracy. Let me start by reading through the input text to spot obvious OCR errors.
#
# Starting with the header: "Copie électronique LABORATOIRE DE BIOLOGIE MEDICALE C LABO   ..." looks okay except maybe "électronique" might be "électronique" is correct, but maybe "C LABO" is part of the lab's name. The FINESS number has some numbers, but I shouldn't change those unless clearly wrong. The patient's name is   , which seems correct.
#
# Looking at the first section under "Hémogramme", there's "HEMATIEs" which should be "Hématies" but maybe the OCR messed up the accents. Wait, the original has "HEMATIE" written as "HEMATIE" but in French, it's "Hématies". But the user says not to alter valid terms, so maybe leave as is unless it's an obvious typo. Wait, the value "4,94 Téra/L" – "Téra/L" is probably "T/L" (terre/Liter? No, likely "T/L" for tera/L? Wait, in blood tests, Hématies are usually in 10^12/L, so maybe "Téra/L" is a typo for "10^12/L" but the OCR misread "10^12" as "Téra". But the user says not to alter valid terms, so maybe leave as is unless it's clearly wrong. Alternatively, "Téra/L" might be "T/L" (terre/L?), but perhaps it's a unit error. Hmm, but the user wants only to fix OCR artifacts, so if "Téra/L" is incorrect, maybe it should be "10^12/L" but since it's a unit, maybe the correct unit is "10^9/µL" or similar. Wait, the value is 4.94, which is within the normal range for Hématies (usually 4.2-5.9 for males, but the reference here is 3.80-5.90, so maybe the unit is correct as T/L (terre/L?), but perhaps it's a typo for "10^12/L". Alternatively, maybe "Téra/L" is a misread of "10^12/L". But since the user says not to alter valid terms, unless it's an OCR error. Maybe "Téra/L" is incorrect, but I'm not sure. Let me check the reference values. The reference for Hématies is 3.80-5.90, which matches the value 4.94, so the unit might be 10^12/L, but the OCR might have misread "10^12" as "Téra". Alternatively, maybe it's "10^9/µL" but the value 4.94 would be too high. Hmm, perhaps better to leave as is unless it's a clear OCR error.
#
# Looking further, "Hemoglobine" is written as "HEMOGIODINGING" – that's definitely an OCR error. The correct term is "Hémoglobine". So I need to correct that. Similarly, "HEMATOCRITE" is correct, but the value is 41.1%, which is okay.
#
# Under Leucocytes, "Polynucléaires neutrophiles" has "Polynucléaires" missing an 'c' in "nucléaires" – the OCR missed a character. Wait, the original might have "Polynucléaires" but the correct spelling is "Polynucléaires" (with an 'n')? Wait, no, the correct term is "Polynucléaires" (with an 'n')? Wait, actually, the correct term is "Polynucléaires" (with an 'n')? Wait, no, the correct French term is "Polynucléaires" (with an 'n'), so maybe the OCR missed an 'n'? Wait, the original text says "Polynucléaires neutrophiles" – maybe the OCR missed an 'n'? Or maybe it's correct. Alternatively, maybe "Polynucléaires" is correct. Wait, the term is "polynucléaires", so maybe the OCR missed an 'n'? Let me check the French spelling. The correct term is "polynucléaires" (with an 'n'), so if the text has "Polynucléaires" with an 'n', then it's correct. Wait, the user's input has "Polynucléaires" with an 'n', so that's okay.
#
# Looking at "Valeurs de référence" sections, some values have "Inf. a" which is "Inf. à" (inférieur à). The OCR might have missed the cedilla. So "Inf. a" should be "Inf. à". Also, "C.C.M.LH." might be "C.M.C.LH." but not sure. Wait, "C.C.M.LH" – maybe "C.M.C.LH" but perhaps it's "C.M.C.LH" (C.M.C. could be "Cylindre" or something else. Alternatively, maybe "C.C.M.LH" is "C.M.C.LH" but I'm not sure. Maybe leave as is unless it's an obvious typo.
#
# In the "Sérologie SARS-CoV-2" section, "Négatif" should be "Négatif" but the OCR might have "Négatif" as correct. Wait, "Négatif" is correct in French.
#
# Looking at the dates and numbers, "01/02/21" is okay.
#
# Now, checking for stray symbols. The user mentioned removing non-text noise like stray symbols. There are some symbols like "Y" or "X" in the text. For example, "X Demande n° 01/02/ -LABO--TP" – the "X" before "Demande" is probably a stray symbol from the OCR, so remove it.
#
# Also, in the "Valeurs de référence" for "FERRITINE" (assuming that's the term), there's "43 ng/mt" – "ng/mt" might be "ng/mL" (ng/mL for nanograms per milliliter). The OCR might have misread 'mL' as 'mt'. So correct "ng/mt" to "ng/mL".
#
# Looking at "Cholestérol L.D.L." – the correct term is "Cholestérol LDL", but the OCR might have misread "L.D.L" as "LDL". Wait, the user says not to alter valid terms, so if it's written as "L.D.L" but the correct is "LDL", but maybe it's just a formatting issue. Alternatively, "Cholestérol L.D.L" might be "Cholestérol LDL". The value is 1.74 mmol/L, which is LDL cholesterol. So perhaps correct "L.D.L" to "LDL". But the user says not to alter valid terms. Wait, the original might have "L.D.L" as a typo, but if it's a valid term, leave it. Alternatively, maybe it's "LDL" but the OCR split it. Since the user says not to alter valid terms, perhaps leave as is unless it's clearly wrong.
#
# Looking at "" – the lab name is "" but maybe it's " " or "Labo Sud"? Wait, the lab name is " " in the header, so "" might be a typo. Wait, in the input text, the lab is " ", so "" in the body might be a typo from OCR. The original might have " " but OCR read "". So correct "" to " ".
#
# Also, " " is probably " " (the name of the biologist). The OCR might have misread 'e' as 'f'? Or maybe it's correct. The name is written as " " in the header, so in the body, " " should be " ". So correct that.
#
# Looking at "FSE Tiers payant " – "" might be "" which are social security codes, so leave as is.
#
# In the "Transaminases S.G.O.T. (ASAT)" – the acronym S.G.O.T. should be "ASAT" (ASAT is aspartate aminotransférase, so S.G.O.T. is SGOT, which is the old name for ASAT. So "S.G.O.T. (ASAT)" is correct.
#
# In the "Glycémie a Jeun" – "a Jeun" should be "à jeun" with accents. The OCR missed the accents. So correct "a Jeun" to "à jeun".
#
# Under "Cholestérol H.D.L." – "H.D.L" should be "HDL" (HDL cholesterol). The OCR might have split it as "H.D.L". So correct "H.D.L" to "HDL".
#
# Looking at "Valeurs de référence" for "FERRITINE" (assuming "FERRITINE" is "Ferritine" (Ferritine), but the OCR might have missed a letter. Wait, the input has "FOSritiNe 10..." which is "Ferritine" misread as "FOSritiNe". So correct "FOSritiNe" to "Ferritine".
#
# Also, "Transaminases S.G.P.T. (ALAT)" – "S.G P.T." should be "S.G.P.T." but maybe it's "S.G.P.T." for S.G.P.T. (SGPT, which is ALAT). The OCR might have missed a period.
#
# In the "Conclusion" section, "Bilan lipidique a interpréter" should be "à interpréter" with an accent.
#
# Looking at the "DFG estimé d'aprés Lewey (MDRD)" – "Lewey" is likely "Lewey" but the correct term is "MDRD" (Modification of Diet in Renal Disease equation). The OCR might have "Lewey" as a typo for "MDRD" equation. Wait, the input says "d'aprés Lewey (MDRD)", so "Lewey" is probably a typo for "MDRD" equation. Wait, the correct equation is MDRD, so "Lewey" is an OCR error. So correct "Lewey" to "MDRD".
#
# Also, "CKD-EPI" is correct.
#
# In the "Interprétation" section, "Débit de Filtration Glomérulaire legérement diminué" – "legérement" should be "légerement" with an accent.
#
# In the "Sérologie" section, "Négatif" is correct.
#
# Looking at the URLs: "https://.fr/espace-pro/" – the correct URL might be "https://.fr/espace-pro/" but maybe it's correct.
#
# In the "FSE Tiers payant  - " – "" might be a code, leave as is.
#
# Checking for stray symbols like "Y" or "X" – in the first page, "X Demande n°" has an 'X' before "Demande", which is a stray symbol, so remove it.
#
# Also, "Page 1/5" has some symbols like "a" with accents missing.
#
# In the "Interprétation" section, "Interprétation" is missing an accent on "Interprétation" → "Interprétation" should be "Interprétation" with an accent on "é".
#
# Looking at "  Biologiste" – the name is " " but the header has " ", so correct to " ".
#
# In the "Créatinine" section, "9,3 mg/L" – the unit should be "mg/L" but maybe it's "mg/dL"? Not sure, but the reference is 5.1-9.5, so probably correct.
#
# In the "Ferritine" section, "15,3 pmol/L" – "pmol/L" is picomoles per liter, so correct "pmol/L" as "pmol/L" is okay.
#
# In the "Transferrine" section, "2,4 g/t" should be "g/L" (g/L) but the unit is grams per liter, so "g/L" is okay.
#
# In the "Cholestérol Total", "3,53 mmol/L" – the unit is correct.
#
# In the "Interprétation" section, "RCV" is "RCV" (Risque Cardio-Vasculaire), so correct "RCV" as is.
#
# In the "Hormonologie" section, "FSE Tiers payant " – "FSE" might be "FSE" as is.
#
# In the "Ferritine" section, "85 yg/100mL" – "yg/100mL" is micrograms per 100 mL, so "yg/100mL" is correct.
#
# In the "Thyroide" section, "T.S.H. ultra-Sensible" should be "TSH ultra-sensible", but the OCR might have "T.S.H." as correct.
#
# Looking at "  Biologiste" – correct to " " as per header.
#
# In the "Interprétation" section, "Interprétation" needs an accent on "Interprétation".
#
# In the "Sérologie" section, "Négatif" is correct.
#
# In the "Conclusion", "Bilan lipidique a interpréter" should be "à interpréter" with an accent.
#
# Also, in the "Valeurs de référence" for "Ferritine", "9,0 4 30,4" – the "4" is "à" (à 30,4). So replace "4" with "à".
#
# In the "Transferrine" section, "30,2 mol/L" – "mol/L" is micromoles per liter? The value is 30,2 µmol/L? The unit might be "µmol/L", so correct "mol/L" to "µmol/L" if it's a typo. The input has "30,2 mol/L" but the unit is likely "µmol/L", so correct "mol" to "µmol".
#
# Also, "C.C.M LH" in "C.C.M LH" – maybe "C.M.C. LH" but not sure.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# In the "Sérologie" section, "Négatif <1 ; Positif > 1" – correct.
#
# In the "Thyroide" section, "T.S.H. ultra-Sensible" – "TSH" is correct.
#
# In the "Interprétation" section, "DFG estimé d'aprés Lewey" – "Lewey" should be "MDRD" (MDRD equation). The correct equation is MDRD, so "Lewey" is an OCR error. So correct "Lewey" to "MDRD".
#
# Also, "CKD-EPI" is correct.
#
# In the "Interprétation" section, "Interprétation" has a typo "Interprétation" with missing accent.
#
# In the "Ferritine" section, "15,3 pmol/L" is okay.
#
# In the "Transferrine", "30,2 mol/L" – "mol" should be "µmol" (micromoles). So "30,2 µmol/L". The OCR might have missed the mu symbol, so correct "mol" to "µmol".
#
# In the "Cholestérol Total" section, "3,53 mmol/L" is correct.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# In the "Sérologie" section, "Négatif" is correct.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# Also, in the "Interprétation" section, "Interprétation" should be "Interprétation" with an accent on "é".
#
# Now, checking for stray symbols:
#
# - The "X Demande n°..." has an 'X' before "Demande", remove it.
#
# - The "Y" in "Y Demande" – no, that's part of the name.
#
# - The "Y" in " " is correct.
#
# - The "X" in "X Demande" is a stray symbol.
#
# Also, in the "Interprétation" section, "Interprétation" has a missing accent.
#
# Now, looking for other OCR errors like "" instead of " " or "Labos Sud". The lab name is " ", so "" is an OCR error. Correct "" to " ".
#
# In the "Interprétation" section, "Interprétation" should be "Interprétation" with an accent.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# Also, " " is correct.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# In the "Interprétation" section, "Interprétation" needs an accent.
#
# Now, going through each section step by step:
#
# First page:
#
# - Remove the "X" before "Demande n°..."
#
# - Correct "" to " " wherever it appears.

# %% [markdown]
# ### Easy OCR input

# %%
import os


from groq import Groq


client = Groq(

    # This is the default and can be omitted

    api_key=os.environ.get("GROQ_API_KEY"),

)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "You are an expert in cleaning OCR-extracted medical documents. "
                "Your task is to correct errors while preserving clinical accuracy. "
                "Follow these rules strictly:\n"
                "1. Fix OCR artifacts (e.g., 'c0ugh' → 'cough'), but NEVER alter valid medical terms.\n"
                "2. Remove non-text noise (stray symbols, headers/footers).\n"
                "3. Retain original formatting (lists, bullet points) where meaningful.\n"
                "4. Return ONLY the cleaned text, no explanations."
            )
        },
        {
            "role": "user",
            "content": (
                "Denoise this OCR-extracted medical document for embedding:\n\n"
                "=== INPUT TEXT ===\n"
                f"{open('task2_prompts/prompting_easy.txt', encoding='utf-8').read()}\n"
                "=== END INPUT ==="
            )
        }
    ],
    model="qwen-qwq-32b",
    temperature=0.2,  # Reduce randomness for factual accuracy
    max_tokens=4096   # Ensure long documents are fully processed
)



print(chat_completion.choices[0].message.content)
# Out:
# <think>
# Okay, let's tackle this OCR cleaning task. First, I need to go through the provided document carefully. The user wants me to correct OCR errors but keep the clinical terms accurate.
#
# Starting with the header: "Copie électronique LABORATOIRE DE BIOLOGIE MÉDICALE 6  ..." looks okay except maybe "6  " might be a typo? Wait, maybe it's part of the lab's name. I'll leave it as is unless there's an obvious error.
#
# Looking at the patient info: "Madame    CABINET..." – "CABINET" might be "CABINET" but probably "CABINET MEDICAL" should be "CABINET MÉDICAL" with an accent. Wait, in the original, it's written as "CABINET MEDICAL " "      (100)". "" is likely "CAME" (rue CAME DES ?), but maybe "" is a street name, so maybe it's correct. Hmm, but "" might be "" as a street name. I'll check if "" is a known street, but since I can't verify, I'll leave it as is.
#
# Next, "Demande n' 01/02/ ~LABO--TP" – the apostrophe after "Demande n'" might be a typo. It should probably be "Demande n° 01/02/" with a degree symbol, but maybe just correct the apostrophe to a degree symbol or remove it if unsure. Wait, the user says not to alter valid terms. Maybe it's "Demande n°" but the OCR might have misread the degree symbol as an apostrophe. So changing "n' " to "n°" would be correct.
#
# Looking at the lab results: "Hématies 4,94 Téra/L" – "Téra/L" is likely "Tera/L" but in French, they use "Téra" for tera, so that's correct. The value is within the reference range.
#
# In the leucocytes section: "Polynucléaires neutrophiles 58,1 % 3,780 G/L 1,40 à 7,70 4,240" – "Polynucléaires" should be "Polynucléaires" but maybe it's "Polynucléaires" with a typo in "nucléaires" – perhaps "nucléaires" is correct. Wait, "Polynucléaires" is correct for "polynucléaires" (polymorphonucléaires?), but maybe the OCR missed a 'm'? Not sure, but I'll keep it as is unless there's an obvious mistake.
#
# The "Ferritine 2,4 g/L" – wait, ferritin is usually in ng/mL or µg/L. Wait, in the text, it says "Transferrine 2,4 g/L" – that can't be right. Wait, checking the original input: "Transferrine 2,4 g/L 2,0à 3,6 (Sang Immunoturbidimétrie Roche)". Wait, transferrin is measured in g/L? That seems high. Wait, maybe it's "g/L" but the normal range for transferrin is around 2-3.5 g/L, so that's correct. So that's okay.
#
# Looking for OCR errors like "" instead of " "? Wait, in the document, " " – that's probably a typo from OCR, since the lab is  . So "" should be " ". Wait, the original input has " " multiple times. That's an OCR error, so correct to "  ".
#
# Also, "" in URLs: "https:/ I  fr/depistage-covid-19/" – the URL should be "https:// .fr/depistage-covid-19/" – adding the missing slash and fixing "I " to " ". Also, "" in "ABC juilletaoût 2017" should be "juillet-août".
#
# Check for numbers: "" – dates are okay. "VPM 9,7 fL Inf. à 11,0 10,2" – "VPM" is probably "VPM" (Volume Plaquettaire Moyen?), which is a valid term.
#
# In the immunology section: "Sérologie_SARS-CoV-2 (Covid-19)" – "Covid" should be "Covid". Correct that to "Covid-19" → "Covid-19".
#
# Check for stray symbols: "Edité le, lundi 1 février 2021" – the comma after "le" is extra, but the user says to remove non-text noise. Maybe the comma is part of the text, so leave it unless it's a typo. The OCR might have added an extra comma, but the user says to remove non-text noise, but the comma is part of the date format. So leave as is.
#
# In the disclaimer part: "Y'agissant du traitement de vos données personnelles..." – "personnelles" should be "personnelles" but maybe "personnelles" is a typo. Wait, original text says "personnelles" with an 's'? Wait, in the input, it's written as "personnelles" – maybe "personnelles" is a typo for "personnelles" (with an 's'). Wait, the correct French is "personnelles" (données personnelles) – no, "personnelles" is correct? Wait, "personnelles" with an 's'? No, "personnelles" is correct. Wait, "personnelles" – maybe "personnelles" is correct. Wait, the user says not to alter valid terms, so if it's a typo, but maybe it's correct. Alternatively, maybe "personnelles" is a mistake for "personnelles" but I'll check. Alternatively, maybe "personnelles" is correct. Hmm, perhaps it's better to leave as is unless it's clearly wrong.
#
# In the URL: "https:/ I  fr/depistage-covid-19/" – missing "www" or "www."? The correct URL would be "https://www. .fr/depistage-covid-19/". But the original has "I " which is an OCR error. So correct to " .fr".
#
# Also, "" in "https:l/ frlespace-prol" – should be "" is part of the URL? Maybe "" is correct, but maybe "" is a typo for "" (maybe a brand name?), so leave as is unless it's a known error. The user says not to alter valid terms, so if "" is the correct name, leave it.
#
# Check for numbers: "43 ng/mL" – ferritin 43 ng/mL is okay. "97 pmol/L" – maybe "97 pmol/L" should have a slash? Like "pmol/L" is okay.
#
# In the disclaimer: "Conformément la réglementation sur la protection des données personnelles" – "Conformément" should be "Conformément" with an 'f'? Wait, "Conformément" is correct. Wait, the original says "Conformement la réglementation" – "réglementation" is "réglementation" but should be "réglementation" → "réglementation" is incorrect, should be "réglementation" → "réglementation" has a typo. Wait, "réglementation" is "réglementation" but the correct French is "réglementation" → "réglementation" is misspelled. Wait, "réglementation" is "réglementation" but the correct spelling is "réglementation" → "réglementation" is correct? Wait, "réglementation" is misspelled as "réglementation" (missing an 'e'?), maybe "réglementation" → "réglementation" → actually, "réglementation" is misspelled. The correct French is "réglementation" → "réglementation" has a typo. Wait, "réglementation" should be "réglementation" with an 'e'? Wait, the correct spelling is "réglementation" → "réglementation" is correct. Wait, maybe the OCR misread "réglementation" as "réglementation". Wait, "réglementation" is actually "réglementation" with an 'e' missing? Not sure, but since I can't confirm, maybe leave as is.
#
# Also, "Y'agissant du traitement" – the apostrophe might be an OCR error. Maybe "Y'agissant" should be "Y'agissant" is correct, but maybe it's "Y'agissant" with a space? Or maybe "Y'agissant" is correct.
#
# Check for "Valeur recommandée < 4,12 mmol/L soit 1,60 g/L (HASIAFSSAPS 2017)" – "HASIAFSSAPS" is probably "HAS/AFSSAPS" (HAS and AFSSAPS are French health authorities). So correct to "HAS/AFSSAPS".
#
# In the URL: "https:Hl frlespace-prol" – the original has "https:l/ frlespace-prol" – need to correct to "https://.fr/lespace-pro/" or similar. The original input has "https:l/ frlespace-prol" – so correct to "https://.fr/lespace-pro/".
#
# Also, "www   fr" should be "www. .fr".
#
# Check for "Page 1/5" and "Page 2/5" etc., those are okay.
#
# In the immunology section: "Sérologie_SARS-CoV-2 (Covid-19)" – "Covid" is a typo for "Covid" → "Covid" should be "Covid-19" → correct to "Covid-19".
#
# In the disclaimer: "Y'agissant du traitement" – the apostrophe might be an OCR error. Maybe "Y'agissant" should be "Y'agissant" is correct.
#
# Also, "Inf. à 11,0 10,2" – "Inf. à" is "Inf. à" meaning "Inf. à" (inférieur à), so okay.
#
# Check for " " – the name is "" but maybe it's "" or "" is correct. The original has " " – maybe " " is correct, but the user says not to alter names. So leave as is.
#
# In the section "DFG estimé d'après Lewey (MDRD)" – "Lewey" is likely "Lewey" but the correct term is "MDRD" (maybe "MDRD" is correct, as in MDRD equation for GFR). The MDRD equation is a standard term, so "MDRD" is correct. The user says not to alter valid terms, so leave as is.
#
# "CKD-EPI" is correct as a standard term.
#
# In the disclaimer: "Y'agissant du traitement" – maybe "Y'agissant" should be "Y'agissant" is correct.
#
# Also, "  Biologiste" – "" might be "" as the name, so leave as is.
#
# Check for "FSE Tiers payant  " – "" might be "" as codes, so leave as is.
#
# "Vitesse de sédimentation 11 mm Inf à 26" – "Inf à" is "Inf. à" with a space, but the original has "Inf à" so maybe add a period? The user says to retain formatting, so leave as is.
#
# In the URL: "https://  fr/politique-de-confidentialite-rgpa/" – "fr/politique-de-confidentialite-rgpa/" should be "fr/politique-de-confidentialite-rgpd/"? The original has "rgpa" but maybe it's "rgpd" (RGPD is General Data Protection Regulation). So "rgpa" is likely a typo for "rgpd". So correct "rgpa" to "rgpd".
#
# Also, "politic" might be "politique" but in the input it's "politique-de-confidentialite-rgpa" → "politique" is correct (French for "policy"), so "politique-de-confidentialite-rgpa" → "politique-de-confidentialite-rgpd".
#
# Also, "Y'agissant du traitement" – maybe "Y'agissant" is correct, but the apostrophe might be an OCR error. Maybe "Y'agissant" is correct.
#
# Check for "FSE Tiers payant  " – "" is likely correct as insurance codes.
#
# In the immunology section: "Hormonologie" – no, the input has "Hormonologie" but the original says "Hormonologie" – maybe "Hormonologie" is correct (endocrine system), so leave as is.
#
# In the transferrin section: "Capacité totale de saturation" – "totale" should be "totale" → "totale" is a typo for "totale"? Wait, the input has "Capacité totale de saturation" → "totale" is misspelled as "totale" (should be "totale" → "totale" is correct? No, "totale" is misspelled. The correct term is "totale" → "totale" is misspelled as "totale". Wait, "totale" is incorrect, should be "totale"? Wait, "capacité totale" is "totale" which is misspelled. The correct French is "totale" → "totale" with an 'e'? Wait, "capacité totale" → "totale" is correct? No, "totale" is misspelled. The correct term is "totale" (with an 'e')? Wait, "capacité totale" → "totale" is misspelled. The correct French is "totale" → "totale" is incorrect. Wait, "totale" is correct? No, "totale" is misspelled. The correct spelling is "totale" → "totale" is correct? Wait, "totale" is correct. Wait, "totale" is the correct spelling in French for "totale" (total). So "totale" is correct. Wait, "totale" is correct. Wait, "totale" is correct. Maybe it's correct. Alternatively, maybe "totale" is a typo for "totale" – but I can't be sure, so leave as is.
#
# Check for "  Biologiste" – "" might be "" as the name, so leave as is.
#
# In the disclaimer: "Y'agissant du traitement de vos données personnelles" – "personnelles" should be "personnelles" → "personnelles" is correct? "personnelles" is misspelled as "personnelles" (with an 's' at the end). The correct French is "personnelles" with an 's'? Wait, "personnelles" is correct. "Données personnelles" is "personnelles" with an 's'? Wait, "personnelles" is correct. Wait, "personnelles" with two 'l's? The correct spelling is "personnelles" with two 'l's? Let me think: "personnelles" in French is spelled with two 'l's: "personnelles". The input has "personnelles" with one 'l'? Let me check the input text. The original input has "donnees personnelles" → "personnelles" with one 'l'? Wait, the user's input has "donnees personnelles" → "personnelles" with one 'l'? The correct spelling is "personnelles" with two 'l's. So correct to "personnelles".
#
# But the user says not to alter valid terms. If the original has "personnelles" with one 'l', maybe it's an OCR error. But since I can't be sure, maybe leave as is unless it's a clear OCR error. The correct spelling is "personnelles" with two 'l's. So "personnelles" is misspelled. But since it's part of a disclaimer, maybe the lab's document has a typo, but per the user's instruction, only correct OCR errors, not document errors. So leave as is.
#
# Another part: "Y'agissant du traitement" – the apostrophe might be an OCR error. Maybe it should be "Y'agissant" → "Y'agissant" is correct.
#
# In the URL: "https:Hl frlespace-prol" → correct to "https://.fr/lespace-pro/".
#
# Also, "https:/ I  fr/depistage-covid-19/" → correct to "https:// .fr/depistage-covid-19/" → "depistage" should be "dépistage" but in URL, it's "depistage" → maybe "depistage" is correct as per the lab's URL.
#
# "  Biologiste" – "Biologiste" is correct.
#
# In the disclaimer: "Y'agissant du traitement" → maybe "Y'agissant" is correct.
#
# Also, "  Biologiste" – "Biologiste" is correct.
#
# Check for "FSE Tiers payant  " – codes are okay.
#
# In
